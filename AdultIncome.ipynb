# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.patches as mpatches

# %%
data = pd.read_csv('/content/adult.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  ... hours-per-week  native-country income
# 0   25    Private  226802  ...             40   United-States  <=50K
# 1   38    Private   89814  ...             50   United-States  <=50K
# 2   28  Local-gov  336951  ...             40   United-States   >50K
# 3   44    Private  160323  ...             40   United-States   >50K
# 4   18          ?  103497  ...             30   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
data['salary'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64

# %%
#Data cleaning
from numpy import nan
data = data.replace('?', nan)
data.head()
# Out:
#    age  workclass  fnlwgt  ... hours-per-week  native-country income
# 0   25    Private  226802  ...             40   United-States  <=50K
# 1   38    Private   89814  ...             50   United-States  <=50K
# 2   28  Local-gov  336951  ...             40   United-States   >50K
# 3   44    Private  160323  ...             40   United-States   >50K
# 4   18        NaN  103497  ...             30   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
data.isnull().sum() / data.shape[0]*100
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
print('workclass',data['workclass'].unique())
print('education',data['education'].unique())
print('marital-status',data['marital-status'].unique())
print('occupation',data['occupation'].unique())
print('relationship',data['relationship'].unique())
print('race',data['race'].unique())
print('gender',data['gender'].unique())
print('native-country',data['native-country'].unique())
# Out:
# workclass ['Private' 'Local-gov' nan 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# education ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
# marital-status ['Never-married' 'Married-civ-spouse' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
# occupation ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' nan
#  'Other-service' 'Prof-specialty' 'Craft-repair' 'Adm-clerical'
#  'Exec-managerial' 'Tech-support' 'Sales' 'Priv-house-serv'
#  'Transport-moving' 'Handlers-cleaners' 'Armed-Forces']
# relationship ['Own-child' 'Husband' 'Not-in-family' 'Unmarried' 'Wife' 'Other-relative']
# race ['Black' 'White' 'Asian-Pac-Islander' 'Other' 'Amer-Indian-Eskimo']
# gender ['Male' 'Female']
# native-country ['United-States' nan 'Peru' 'Guatemala' 'Mexico' 'Dominican-Republic'
# ...

# %%
data['native-country'].fillna(data['native-country'].mode(),inplace=True)
data['workclass'].fillna(data['workclass'].mode()[0],inplace = True)
data['occupation'].fillna(data['workclass'].mode()[0],inplace = True)

# %%
data.isnull().sum() / data.shape[0]*100
# Out:
# age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %%
sns.pairplot(data)

# %%
data['age'].hist(figsize = (10,5))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data['fnlwgt'].hist(figsize = (10,5))
plt.show()

# %%
data['capital-gain'].hist(figsize =(10,5))
plt.show()

# %%
data['capital-loss'].hist(figsize = (10,5))
plt.show()

# %%
data['hours-per-week'].hist(figsize = (10,5))
plt.show()

# %%
#Relationship between capital-gain and capital-loss
sns.relplot(data['capital-gain'],data['capital-loss'])
plt.xlabel('capital-gain')
plt.ylabel('capital-loss')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Workclass Distribution
plt.figure(figsize=(12,5))

total = float(len(data['income']))

a = sns.countplot(x='workclass',data= data)

for f in a.patches:
    height = f.get_height()
    a.text(f.get_x() + f.get_width()/2., height+3, '{:1.2f}'.format((height/total)*100),ha="center")
plt.show()

# %%
#Education Distribution
plt.figure(figsize=(20,5))

a= float(len(['income']))

a= sns.countplot(x='education',data=data)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
#Marital-Status Distribution
plt.figure(figsize=(20,5))

a= float(len(['income']))

a= sns.countplot(x='marital-status',data=data)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
#Occupation Distribution
plt.figure(figsize=(18,6))

a= float(len(['income']))

a= sns.countplot(x='occupation',data=data)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
#Relationship Status
plt.figure(figsize=(18,6))

a= float(len(['income']))

a= sns.countplot(x='relationship',data=data)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
#Race Distribution
plt.figure(figsize=(18,6))

a= float(len(['income']))

a= sns.countplot(x='race',data=data)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
#Gender Distribution
plt.figure(figsize=(12,8))

a= float(len(['income']))

a= sns.countplot(x='gender',data=data)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
#General income distrubition
plt.figure(figsize=(12,8))

a= float(len(data))

a= sns.countplot(x='income',data=data)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
#Boxplot(Age relationship with income)
fig = plt.figure(figsize=(5,5))
sns.boxplot(x='income',y='age',data=data).set_title('Box plot of Income and Age')
plt.show()

# %%
#Boxplot(workclass relationship with income)
fig = plt.figure(figsize=(10,5))
sns.countplot(x='workclass',hue ='income',data=data).set_title("workclass vs count")
# Out:
# Text(0.5, 1.0, 'workclass vs count')

# %%
#Boxplot (capital-gain Relationship with income)
fig = plt.figure(figsize=(5,5))
sns.boxplot(x='income',y='capital-gain',data=data).set_title('Box plot of Income and Capital-Gain')
plt.show()

# %%
#Boxplot (capital-loss Relationship with income)
plt.figure(figsize=(5,5))
sns.boxplot(x="income", y="capital-loss", data=data).set_title('Box plot of Income and Capital-Loss')
plt.show()

# %%
#Boxplot (relationship Relationship with income)
plt.figure(figsize=(10,8))
sns.countplot(x='relationship',hue='income',data=data).set_title('Relationship vs count')
plt.show()

# %%
#Boxplot (race Relationship with income)
plt.figure(figsize=(12,8))
sns.countplot(x ='relationship',hue='income',data = data).set_title('Relatioship and Count')
plt.show()

# %%
#Boxplot (race Relationship with income)
plt.figure(figsize=(20,5))
sns.catplot(y="race", hue="income", kind="count",col="gender", data=data);
plt.show()

# %%
sns.heatmap(data.corr())
